# %% [markdown]
# ## **Работа с кодом: модули и импорт**

# %% [markdown]
# Часто возникает необходимость что бы использовать классы, функции или другие переменные которые мы объявили в одном файле, при исполнение кода в другом.

# %%
import exemption # импортируемый модуль.

print(exemption.greet("Student"))
# Out:
# Hello, im is module from exemption.py
# Hello, Student

# %% [markdown]
# #### *Интерпретатор CLI также поддерживает импорт модулей.*

# %% [markdown]
# ![](../Paste_image/2022-05-25-10-10-27.png)

# %% [markdown]
# ### **Проблемы возникающие при импорте модулей.**

# %% [markdown]
# Исполнение части импортированного кода

# %%
import exemption # импортируемый модуль.
import fib

print(exemption.greet("Student"))
# Out:
# fib
# 2178309
# Hello, Student

# %% [markdown]
# Для того что бы разграничить исполняемый и не исполняемый год существует глобальное имя **___name___**

# %%
# print(__name__)

# def fib(k):
#     if k == 0 or k == 1:
#         return 1
#     else:
#         return fib(k - 1) + fib(k -2)
   
# print(fib(31))

# %%
import fib
print(__name__)
# Out:
# __main__

# %%
# def fib_name(k):
#     if k == 0 or k == 1:
#         return 1
#     else:
#         return fib_name(k - 1) + fib_name(k -2)

# if __name__=="__main__":
#     print(__name__)
#     print(fib_name(31))

# %%
import fib_name

# %%
print(fib_name.fib_name(5))
# Out:
# 8

# %% [markdown]
# ### **Система импорта в языке Python.**

# %% [markdown]
# Схема обращения.
#
# ![](../Paste_image/2022-05-25-11-10-00.png)

# %%
import sys
print(type(sys.modules))
# Out:
# <class 'dict'>

# %%
sys.modules
# Out:
# {'sys': <module 'sys' (built-in)>,
#  'builtins': <module 'builtins' (built-in)>,
#  '_frozen_importlib': <module '_frozen_importlib' (frozen)>,
#  '_imp': <module '_imp' (built-in)>,
#  '_thread': <module '_thread' (built-in)>,
#  '_warnings': <module '_warnings' (built-in)>,
#  '_weakref': <module '_weakref' (built-in)>,
#  '_io': <module '_io' (built-in)>,
#  'marshal': <module 'marshal' (built-in)>,
#  'nt': <module 'nt' (built-in)>,
#  'winreg': <module 'winreg' (built-in)>,
#  '_frozen_importlib_external': <module '_frozen_importlib_external' (frozen)>,
#  'time': <module 'time' (built-in)>,
#  'zipimport': <module 'zipimport' (frozen)>,
#  '_codecs': <module '_codecs' (built-in)>,
#  'codecs': <module 'codecs' from 'c:\\Program Files\\Python310\\lib\\codecs.py'>,
#  'encodings.aliases': <module 'encodings.aliases' from 'c:\\Program Files\\Python310\\lib\\encodings\\aliases.py'>,
# ...

# %% [markdown]
# *Теперь мы можем увидеть импортированные модули*
#
# >'exemption': <module 'exemption' from 'c:\\Users\\anona\\OneDrive\\Документы\\Обучение\\Phyton\\[stepik]  Python основы и применение\\2.2 Работа с кодом модули и импорт\\exemption.py'>,
#
#  >'fib': <module 'fib' from 'c:\\Users\\anona\\OneDrive\\Документы\\Обучение\\Phyton\\[stepik]  Python основы и применение\\2.2 Работа с кодом модули и импорт\\fib.py'>,
#
#  >'fib_name': <module 'fib_name' from 'c:\\Users\\anona\\OneDrive\\Документы\\Обучение\\Phyton\\[stepik]  Python основы и применение\\2.2 Работа с кодом модули и импорт\\fib_name.py'>,

# %%
print(type(fib))
# Out:
# <class 'module'>

# %%
print(id(fib))
# Out:
# 1514886807856

# %%
import fib
print(id(fib))
# Out:
# 1514886807856

# %% [markdown]
# ***Любой модуль может быть исполнен лишь единожды.***

# %% [markdown]
# ### *Список директорий в которых интерпритатор ищет модули.*

# %%
import sys
for path in sys.path:
    print(path)
# Out:
# c:\Users\anona\OneDrive\Документы\Обучение\Phyton\[stepik]  Python основы и применение\2.2 Работа с кодом модули и импорт
# c:\Program Files\Python310\python310.zip
# c:\Program Files\Python310\DLLs
# c:\Program Files\Python310\lib
# c:\Program Files\Python310
#
# C:\Users\anona\AppData\Roaming\Python\Python310\site-packages
# C:\Users\anona\AppData\Roaming\Python\Python310\site-packages\win32
# C:\Users\anona\AppData\Roaming\Python\Python310\site-packages\win32\lib
# C:\Users\anona\AppData\Roaming\Python\Python310\site-packages\Pythonwin
# c:\Program Files\Python310\lib\site-packages

# %% [markdown]
# ##  **Конструкция** *from __ import __* , *as __*

# %%
from exemption import BadName, greet

# %%
BadName
# Out:
# <function exemption.greet(name)>

# %%
greet
# Out:
# <function exemption.greet(name)>

# %%
from exemption import BadName as Name_bad

# %%
Name_bad
# Out:
# exemption.BadName

# %% [markdown]
# *(from exemption import * )* импортировать все
#
# добавить исключение, для импорта возможно добавив нижнее подчеркивание *_BadName* либо определив переменную *__all __* в подключаемом модуле
